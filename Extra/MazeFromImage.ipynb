# %%
import sys
sys.path.append("../")
from Core.maze import Maze

# %%
maze = Maze()
maze.load_from_image("valorant_1.png", 100)
display(maze.draw(cell_width=6))
# Out:
# <PIL.Image.Image image mode=RGBA size=610x610 at 0x7F16CC0D3340>

# %%
maze = Maze()
maze.load_from_image("defectors_logo.png", 100)
display(maze.draw(cell_width=6))
# Out:
# <PIL.Image.Image image mode=RGBA size=610x610 at 0x7F16CC71EB80>
