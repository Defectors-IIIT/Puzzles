# %%
import sys
sys.path.append("../")
from Core.maze import Maze

# %%
maze = Maze()
maze.load_from_image("Valorant_Ascent.jpg", 100)
display(maze.draw(cell_width=6))
# Out:
# <PIL.Image.Image image mode=RGBA size=610x610 at 0x7F63C4674310>

# %%
maze = Maze()
maze.load_from_image("Valorant_Bind.jpg", 100)
display(maze.draw(cell_width=6))
# Out:
# <PIL.Image.Image image mode=RGBA size=610x610 at 0x7F63C4674F70>

# %%
maze = Maze()
maze.load_from_image("Valorant_Haven.jpg", 100)
display(maze.draw(cell_width=6))
# Out:
# <PIL.Image.Image image mode=RGBA size=610x610 at 0x7F63C881F730>

# %%
maze = Maze()
maze.load_from_image("Valorant_Icebox.jpg", 100)
display(maze.draw(cell_width=6))
# Out:
# <PIL.Image.Image image mode=RGBA size=610x610 at 0x7F63C8808F70>

# %%
maze = Maze()
maze.load_from_image("Valorant_Split.jpg", 100)
display(maze.draw(cell_width=6))
# Out:
# <PIL.Image.Image image mode=RGBA size=610x610 at 0x7F63C409F070>
